# %% [markdown]
# <div style="text-align:center;line-height:300%;">
# <font face="XB Zar" size=7>
# <h4>Distance\similarity detection</h4>
#   </font>
# </div>
#
#
# <div style="text-align:center;direction:ltr;line-height:300%;">
# <font face="XB Zar" size=3>
# <h1> writen by Hesam  </h1>
#   </font>
# </div>

# %% [markdown]
# this note book is to show multiple way of calulateing distance or similarity of stock time series

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading data

# %% [markdown]
# you can read on how we ghatered data on Dataset folder and its nootebook
#
#
# **data**:
# 1. Interpolated Price Panel:
#     - adj close price interpolated cosisting of top 50 active compony
# 2. top_50_inc :
#     - indicator of these compony
# 2. en_stock :
#     - English symnol name of these compony

# %% [markdown]
# we only use data frome from `2018-01-01=1396-10-11` to `1402-06-13=2023-09-04`

# %%
df_price = pd.read_csv('./interpolated_top8000.csv',index_col=[0])
df_price = df_price['2018-01-01':]
df_list = pd.read_csv('./wrold.csv',index_col=[0])

# %%
en_stock = []
for stock in (df_price):
    if len(df_price[stock].dropna())>=1749:
        en_stock.append(stock)
en_stock = np.array(en_stock)

# %%
    # j=0
    # for i in l:
    #     if i>=1749:
    #         j+=1

# %%
j
# Out:
# 6149

# %%
# plt.hist(l)
# Out:
# (array([  70.,   73.,   95.,  297.,  339.,  228.,  116.,  154.,  115.,
#         6321.]),
#  array([   0. ,  177.7,  355.4,  533.1,  710.8,  888.5, 1066.2, 1243.9,
#         1421.6, 1599.3, 1777. ]),
#  <BarContainer object of 10 artists>)

# %%
top1000 = df_list[0:1000]['Symbol']

# %% [markdown]
# changing the columns to their English name since matplotlib doesn’t support Persian
#
# and then cacluating their return
#
# $$ r(t) = \frac{P(t) - P(t-1)}{P(t-1)}\times 100$$

# %%
# en_stock = top1000.to_numpy()
df_price_return = df_price.pct_change()*100
# Out:
# C:\Users\Hesam\AppData\Local\Temp\ipykernel_15228\232060707.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   df_price_return = df_price.pct_change()*100

# %%
df_price_return
# Out:
#                 CING      DFLI      OMER      CGAU  HAPPSTMNDS.NS       DEN  \
# Date
# 2018-01-01       NaN       NaN       NaN       NaN            NaN       NaN
# 2018-01-02       NaN       NaN       NaN       NaN            NaN       NaN
# 2018-01-03       NaN       NaN -1.984125 -3.501962            NaN       NaN
# 2018-01-04       NaN       NaN -0.303641  0.000000            NaN       NaN
# 2018-01-05       NaN       NaN -1.421323 -1.209658            NaN       NaN
# ...              ...       ...       ...       ...            ...       ...
# 2023-08-29 -0.149252  4.678358  3.601111  1.848742       0.450850  0.863882
# 2023-08-30 -2.092684  2.793300 -2.406415 -0.990098       0.709262  0.581969
# 2023-08-31 -1.984726 -6.521739 -5.205481 -0.333333       2.145805 -0.021830
# 2023-09-01 -0.311532  1.744184  2.312136 -1.505019      -0.382439  1.823540
# 2023-09-03  0.000000  0.000000  0.000000  0.000000       0.000000  0.000000
#
#                 AVTE       BFC     US.MI  001979.SZ  ...      REPL    9983.T  \
# Date                                                 ...
# 2018-01-01       NaN       NaN       NaN        NaN  ...       NaN       NaN
# 2018-01-02       NaN       NaN       NaN        NaN  ...       NaN  0.000000
# 2018-01-03       NaN -2.125290 -0.358418   2.175009  ...       NaN  0.000000
# 2018-01-04       NaN  0.000000  1.233302   0.387020  ...       NaN  3.406809
# 2018-01-05       NaN  2.262890  0.253804   3.566276  ...       NaN  0.861334
# ...              ...       ...       ...        ...  ...       ...       ...
# 2023-08-29  3.766233 -1.328772  1.214229   2.657343  ... -0.815739  0.423089
# 2023-08-30  0.125159 -2.090554 -0.171388   0.885559  ...  2.273823 -0.631959
# 2023-08-31 -0.687498  1.689810  0.171682  -7.765027  ... -3.405863  1.393095
# 2023-09-01 -1.195724  2.602092  0.000000   3.367497  ... -3.428015 -0.448029
# 2023-09-03  0.000000  0.000000  0.000000   0.000000  ...  0.000000  0.000000
#
#              AKSO.OL  RPOWER.NS       STT   SUSE.DE  3083.TWO      EDIT  \
# Date
# 2018-01-01       NaN        NaN       NaN       NaN       NaN       NaN
# 2018-01-02       NaN  -6.265462       NaN       NaN       NaN       NaN
# 2018-01-03  1.590025   0.175906  0.734069       NaN  1.666668 -2.884609
# 2018-01-04 -1.057530   2.633889  1.077701       NaN -1.288054  1.770166
# 2018-01-05  2.458319   0.427716  0.091374       NaN  0.000000 -0.972872
# ...              ...        ...       ...       ...       ...       ...
# 2023-08-29 -2.919390   4.584523  0.175431 -0.064310  1.909306  0.443459
# 2023-08-30  0.179529  10.684936 -0.102160 -0.128697  2.693203 -0.220756
# 2023-08-31 -0.582434  -5.198025  0.423668  0.193297 -0.456093 -1.438054
# 2023-09-01  0.405589  -0.783288  1.614781  0.192924  0.458183  1.907969
# 2023-09-03  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
#
#              0267.HK       CPF
# Date
# 2018-01-01       NaN       NaN
# 2018-01-02       NaN       NaN
# 2018-01-03 -0.176056 -0.368786
# 2018-01-04  0.352744 -0.235509
# 2018-01-05  0.175737  0.910612
# ...              ...       ...
# 2023-08-29  3.520208  0.579712
# 2023-08-30 -0.629725 -2.766568
# 2023-08-31 -1.267426  0.592759
# 2023-09-01  0.000000  3.064234
# 2023-09-03  0.000000  0.000000
#
# [1777 rows x 7808 columns]

# %%
def plot_stocks(x,y):
    plt.figure(figsize=(30, 4))
    plt.plot(np.arange(x.shape[0]), x + 5, "", c="C3")
    plt.plot(np.arange(y.shape[0]), y - 5, "", c="C0")
    plt.axhline(y = 4+5, color = 'r', linestyle = '-')
    plt.axhline(y = -4+5, color = 'r', linestyle = '-')
    plt.axhline(y = 4-5, color = 'b', linestyle = '-')
    plt.axhline(y = -4-5, color = 'b', linestyle = '-')
    plt.axis("off");

# %% [markdown]
# amazon and apple plot

# %%
plot_stocks(df_price_return['AMZN'],df_price_return['AAPL'])

# %% [markdown]
# some stocks have been around less than others

# %% [markdown]
# ## calculated distance/sim adjacency matrix

# %% [markdown]
# DTW stands for Dynamic Time Warping, which is a technique used to measure the similarity between two sequences of feature vectors. It is widely used in speech recognition, handwriting recognition, and music analysis.
#
# The DTW algorithm finds the optimal matching between two sequences by warping the time axis of one sequence to match the other sequence. The cost of the matching is determined by comparing the distance between each pair of corresponding feature vectors in the two sequences. The optimal matching is found using dynamic programming to minimize the total cost.
#
# Let $X$ and $Y$ be two sequences of feature vectors, where $x_i$ is the $i$th feature vector in sequence $X$, and $y_j$ is the $j$th feature vector in sequence $Y$. Let $\text{dist}(x_i, y_j)$ be the distance function that measures the distance between two feature vectors.
#
# The DTW algorithm finds the optimal matching between $X$ and $Y$ using the following dynamic programming algorithm:
#
# \begin{equation}
# \text{DTW}(X,Y) = \min_{\text{path}} \sum_{(i,j)\in\text{path}} \text{dist}(x_i,y_j),
# \end{equation}
#
# where the minimum is taken over all possible paths, and the path is defined as a sequence of pairs $(i,j)$ that represents the corresponding feature vectors in $X$ and $Y$. The dynamic programming algorithm computes the minimum cost of the path that matches each prefix of $X$ to each prefix of $Y$.
#
# The algorithm starts by initializing a cost matrix $C$ of size $(m+1) \times (n+1)$, where $m$ and $n$ are the lengths of $X$ and $Y$, respectively. The cost matrix $C_{i,j}$ stores the minimum cost of the path that matches $x_1,\ldots,x_i$ to $y_1,\ldots,y_j$.
#
# The initialization is done as follows:
#
# \begin{align}
# C_{0,0} &= 0, \\
# C_{i,0} &= \infty, \quad \text{for} \quad i=1,\ldots,m, \\
# C_{0,j} &= \infty, \quad \text{for} \quad j=1,\ldots,n.
# \end{align}
#
# The first row and column are initialized to $\infty$ to ensure that only valid paths are selected in the minimum computation.
#
# The rest of the cost matrix is computed using the following recurrence relation:
#
# \begin{equation}
# C_{i,j} = \text{dist}(x_i, y_j) + \min \{C_{i-1,j}, C_{i,j-1}, C_{i-1,j-1}\},
# \end{equation}
#
# where $\text{dist}(x_i, y_j)$ is the distance between the $i$th feature vector in $X$ and the $j$th feature vector in $Y$, and the minimum is taken over the three adjacent cells.
#
# Finally, the optimal cost of the matching is given by $C_{m,n}$, which is the minimum cost of the path that matches the entire sequences $X$ and $Y$. The optimal path can be found by backtracking from $C_{m,n}$ to $C_{0,0}$ using the adjacent cells with the smallest cost. The resulting path represents the optimal matching between the two sequences.

# %% [markdown]
# we use exisinting repo https://github.com/wannesm/dtaidistance for DTW
#
# I've already cloned this library to the exisitng directory
#
# or you can run the code below to download it
#
# documentation : https://dtaidistance.readthedocs.io/en/latest/index.html
#
# they also implementented C library and it can be acceses by `distance_fast` but you need to have C library install in your PC if you use google colab it won't be a problem

# %%
# !pip install git+https://github.com/wannesm/dtaidistance.git#egg=dtaidistance

# %% [markdown]
# all the modules needed for calculating distance is in distance.py file

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport distance

# %%
from distance import calc_edge,validate_adj

# %%
# en_stock = df_price_return.columns

# %%
en_stock.shape
# Out:
# (6149,)

# %%
size = len(en_stock)
adj = np.zeros((size,size))

# %% [markdown]
# The calc_edge function takes two series and also uses total_ind to returns a similarity score based on the given type. If the type is 1, it calculates a semi-correlation score between the two series based on their properties.
#
# s = minimum lenght of the given two time series
# 1. For type = 1, the function iterates over s1, s2, and totindex in parallel, calling calc_proprty function on each tuple of values and calculating a semi_cor value based on the thresholds provided. The function returns the semi_cor value divided by s.
# 2.
#     - If the type is 2 or 3, it calculates the DTW distance between the two series, type two uses the dulfault euclidean distance between two point
#       while type 3 is customized for by the parameter explained below :
#   `dtw.distance(s1.to_numpy(), s2.to_numpy(), window=4, inner_dist=my_dist(), penalty=1, use_pruning=True, only_ub=True, max_step=4)`
#   my_dist() refers to a custom distance function that can be specified to define how the distance should be calculated between individual elements in the time series.
# T   he parameters window and max_step define constraints on how far the algorithm is allowed to look back or forward in time to match corresponding elements in the two time series.        penalty is a scaling factor applied to the DTW distance.
#
#     - The parameters use_pruning and only_ub refer to optimizations in the DTW algorithm that can significantly improve performance for longer time series. use_pruning enables pruning of candidate warping paths, while only_ub specifies that only the upper bound of the DTW distance should be computed.
#
#     - finally, the expression dtw.distance(s1.to_numpy(),s2.to_numpy(),window=4,inner_dist=my_dist(),penalty=1,use_pruning=True,only_ub=True,max_step=4)/s divides the DTW distance by the length of time series s. This normalization is commonly used to compare DTW distances between time series with different lengths and units, and scales the DTW distance to a value between 0 and 1.
# 3. If the type is 4, it calculates a distance score based on the difference between the two stocks also considering tot_ind,if most of the mraket follows the same pattern that days is not counted, normalized by the number of days.
#
# 4. f the type is 5, it calculates a distance score based on the absolute difference of the stock prices, normalized by the number of days.

# %% [markdown]
# this is a O(N^2) algorithm if the number of stocks gets doubeld the tun time becomes 4 time more than before

# %%
from tqdm import tqdm

# %%
len(df_price_return.columns)
# Out:
# 7808

# %%
# en_stock.shape

# %%
adj.shape
# Out:
# (7808, 7808)

# %%
for i,stock1 in (enumerate(tqdm(en_stock))):
    for j,stock2 in enumerate(en_stock):
        # type of distance
        type = 3
        # since its a symmetric matix we only need to compute it for half of indexes
        if i>j:
            dist = calc_edge(df_price_return[stock1],df_price_return[stock2],type)
            adj[i,j] = dist
            adj[j,i] = dist
if type==1:
    np.fill_diagonal(adj,1)
else:
    np.fill_diagonal(adj,0)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   4%|▎         | 35/1000 [00:02<01:03, 15.12it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\Research\PP_and_OP\Stock_Community_Detection\.conda\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IHC.AE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# e:\Research\PP_and_OP\Stock_Community_Detection\distance_detection\DTW_nootbook.ipynb Cell 34 line 7
#       <a href='vscode-notebook-cell:/e%3A/Research/PP_and_OP/Stock_Community_Detection/distance_detection/DTW_nootbook.ipynb#X45sZmlsZQ%3D%3D?line=4'>5</a> # since its a symmetric matix we only need to compute it for half of indexes
#       <a href='vscode-notebook-cell:/e%3A/Research/PP_and_OP/Stock_Community_Detection/distance_detection/DTW_nootbook.ipynb#X45sZmlsZQ%3D%3D?line=5'>6</a> if i>j:
# ----> <a href='vscode-notebook-cell:/e%3A/Research/PP_and_OP/Stock_Community_Detection/distance_detection/DTW_nootbook.ipynb#X45sZmlsZQ%3D%3D?line=6'>7</a>     dist = calc_edge(df_price_return[stock1],df_price_return[stock2],type)
#       <a href='vscode-notebook-cell:/e%3A/Research/PP_and_OP/Stock_Community_Detection/distance_detection/DTW_nootbook.ipynb#X45sZmlsZQ%3D%3D?line=7'>8</a>     adj[i,j] = dist
#       <a href='vscode-notebook-cell:/e%3A/Research/PP_and_OP/Stock_Community_Detection/distance_detection/DTW_nootbook.ipynb#X45sZmlsZQ%3D%3D?line=8'>9</a>     adj[j,i] = dist
#
# File e:\Research\PP_and_OP\Stock_Community_Detection\.conda\lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File e:\Research\PP_and_OP\Stock_Community_Detection\.conda\lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'IHC.AE'

# %%
np.save('adj_7808',adj)
np.save('7808_names',en_stock)

# %%
np.where(adj==-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Research\PP_and_OP\Stock_Community_Detection\distance_detection\DTW_nootbook.ipynb Cell 36 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Research/PP_and_OP/Stock_Community_Detection/distance_detection/DTW_nootbook.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> np.where(adj==-1)
#
# NameError: name 'np' is not defined

# %%
import multiprocessing as mp

# Step 1: Init multiprocessing.Pool()


# print(results[:10])
#> [3, 1, 4, 4, 4, 2, 1, 1, 3, 3]

# %%
max(adj.flatten())
# Out:
# 42672321.93777931

# %% [markdown]
# validate_adj : given a list of stocks and sim/dist mat type=0:dist or type=1:sim
#
# it prints the most and least alike stocks
#
# you also need to give the labe of stocks according to adj mat for name representation

# %%
validation_list = ['khodro','kh_sapa','foolad','fe_meli','ve_tejarat','vebe_sader','vebe_melat','booali','noori','sh_bandar','sh_teran','shapna','ke_chad','ke_gol','kh_bahman','kh_gostar','opal']
validate_adj(en_stock,adj,type=0,my_stock=validation_list)
# Out:
# khodro     is most like ['khodro' 'kh_sapa' 'kh_gostar' 'kh_bahman'] with distnaced of [0.         2.83163428 4.85877931 6.31743003]
# khodro     is less like ['jam_pilen' 'kaveh' 'foolazh' 'kala'] with distnaced of [10.28961031 10.32637281 10.98236868 12.62180537]
# -----------------------
#
# kh_sapa    is most like ['kh_sapa' 'khodro' 'kh_gostar' 'kh_bahman'] with distnaced of [0.         2.83163428 5.22071812 6.04172043]
# kh_sapa    is less like ['sh_abriz' 'kaveh' 'foolazh' 'kala'] with distnaced of [10.12359429 10.17780581 10.80243283 12.30932412]
# -----------------------
#
# foolad     is most like ['foolad' 'fe_meli' 'fe_khooz' 'ke_gol'] with distnaced of [0.         2.25115997 2.82493257 3.373508  ]
# foolad     is less like ['kh_bahman' 'kh_zamia' 'kh_gostar' 'kala'] with distnaced of [ 8.75695138 10.53594127 10.61019161 10.70313525]
# -----------------------
#
# fe_meli    is most like ['fe_meli' 'foolad' 'fe_khooz' 've_ghadir'] with distnaced of [0.         2.25115997 3.64327955 3.86704779]
# fe_meli    is less like ['kh_bahman' 'kala' 'kh_zamia' 'kh_gostar'] with distnaced of [ 9.23796604 11.01814351 11.04231879 11.36321377]
# -----------------------
#
# ve_tejarat is most like ['ve_tejarat' 'vebe_sader' 'vebe_melat' 've_pasar'] with distnaced of [0.         2.5595728  4.16827863 5.36550841]
# ve_tejarat is less like ['jam_pilen' 'sh_abriz' 'kh_zamia' 'kala'] with distnaced of [ 9.2501743   9.42802085  9.62545308 11.63686242]
# -----------------------
#
# vebe_sader is most like ['vebe_sader' 've_tejarat' 'vebe_melat' 've_pasar'] with distnaced of [0.         2.5595728  4.52305266 5.33331286]
# vebe_sader is less like ['foolazh' 'kh_zamia' 'jam_pilen' 'kala'] with distnaced of [ 8.56822689  9.09686111  9.17008127 11.39209843]
# -----------------------
#
# vebe_melat is most like ['vebe_melat' 've_tejarat' 'vebe_sader' 've_pasar'] with distnaced of [0.         4.16827863 4.52305266 4.92943546]
# vebe_melat is less like ['zob' 'kh_gostar' 'kh_zamia' 'kala'] with distnaced of [ 8.7644929   9.36970106  9.99655313 10.83612957]
# -----------------------
#
# booali     is most like ['booali' 'noori' 'pars' 'jam'] with distnaced of [0.         3.96648784 4.1362386  4.29684289]
# booali     is less like ['kh_bahman' 'kala' 'kh_zamia' 'kh_gostar'] with distnaced of [ 9.37372588  9.53694892 10.85380296 11.38106684]
# -----------------------
#
# noori      is most like ['noori' 'booali' 'pars' 'shapdis'] with distnaced of [0.         3.96648784 4.41642529 4.63524656]
# noori      is less like ['kala' 'he_kashti' 'kh_zamia' 'kh_gostar'] with distnaced of [10.93768445 10.99327194 11.69287304 12.08089395]
# -----------------------
#
# sh_bandar  is most like ['sh_bandar' 'shapna' 'sh_teran' 'sh_abriz'] with distnaced of [0.         2.83764932 3.03492513 3.35772429]
# sh_bandar  is less like ['kh_sapa' 'kh_gostar' 'kh_zamia' 'kala'] with distnaced of [ 9.71463052 10.96924421 11.23261531 11.2882889 ]
# -----------------------
#
# sh_teran   is most like ['sh_teran' 'shapna' 'sh_bandar' 'sh_abriz'] with distnaced of [0.         2.28725471 3.03492513 3.87803131]
# sh_teran   is less like ['kh_bahman' 'kh_gostar' 'kh_zamia' 'kala'] with distnaced of [ 9.32169542 10.34992858 11.22776097 11.88565408]
# -----------------------
#
# shapna     is most like ['shapna' 'sh_teran' 'sh_bandar' 'sh_abriz'] with distnaced of [0.         2.28725471 2.83764932 4.01764047]
# shapna     is less like ['kh_bahman' 'kh_gostar' 'kh_zamia' 'kala'] with distnaced of [ 9.65142969 10.89564699 11.1935025  11.92441566]
# -----------------------
#
# ke_chad    is most like ['ke_chad' 'ke_gol' 'opal' 'foolad'] with distnaced of [0.         2.41897702 3.52987589 3.58630094]
# ke_chad    is less like ['khodro' 'kala' 'kh_zamia' 'kh_gostar'] with distnaced of [ 9.63554182 11.28020999 11.42255473 11.83440003]
# -----------------------
#
# ke_gol     is most like ['ke_gol' 'ke_chad' 'foolad' 'opal'] with distnaced of [0.         2.41897702 3.373508   3.58692902]
# ke_gol     is less like ['he_kashti' 'kala' 'kh_zamia' 'kh_gostar'] with distnaced of [ 9.19746403 11.08916316 11.202827   11.25121613]
# -----------------------
#
# kh_bahman  is most like ['kh_bahman' 'kh_sapa' 'khodro' 'kh_gostar'] with distnaced of [0.         6.04172043 6.31743003 6.83120585]
# kh_bahman  is less like ['noori' 'kaveh' 'jam_pilen' 'kala'] with distnaced of [10.1767559  10.40638501 10.59363147 11.54644688]
# -----------------------
#
# kh_gostar  is most like ['kh_gostar' 'khodro' 'kh_sapa' 'kh_bahman'] with distnaced of [0.         4.85877931 5.22071812 6.83120585]
# kh_gostar  is less like ['foolazh' 'kala' 'kaveh' 'jam_pilen'] with distnaced of [12.44360037 12.69459901 12.73390516 13.21224103]
# -----------------------
#
# opal       is most like ['opal' 've_omid' 've_sandoq' 'jam'] with distnaced of [0.         2.65945278 2.80720644 2.87962562]
# opal       is less like ['kh_bahman' 'kala' 'kh_zamia' 'kh_gostar'] with distnaced of [ 8.3130858   8.84049405 10.57205326 11.14887965]
# -----------------------

# %% [markdown]
# ##
